# %% [markdown]
# <a href="https://colab.research.google.com/github/hoijja-S2/IPColab/blob/main/CH05_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np #이미지는 기본적으로 2차원 배열이기 때문
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPColab/images/images/facenoise.jpg')
print(gimg.shape)
gimg = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg, cmap='gray')
# Out:
# (558, 556, 3)

# %%
outimg = cv2.blur(gimg, (3, 3))
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=556x558>

# %%
outimg = cv2.GaussianBlur(gimg, (3, 3), 5)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=556x558>

# %%
outimage = gimg.copy()
#blurimage = cv2.GaussianBlur(outimage, (7, 7), 5)
blurimage = cv2.medianBlur(outimage, (3, 3))

x = 200 + 70
y = 200 + 60
size = 15

for h in range(y, y+size):
  for w in range(x, x+size):
    outimage[h, w] = 255

cv2_imshow(outimage)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-1935888344.py in <cell line: 0>()
#       1 outimage = gimg.copy()
#       2 #blurimage = cv2.GaussianBlur(outimage, (7, 7), 5)
# ----> 3 blurimage = cv2.medianBlur(outimage, (3, 3))
#       4
#       5 x = 200 + 70
#
# error: OpenCV(4.12.0) :-1: error: (-5:Bad argument) in function 'medianBlur'
# > Overload resolution failed:
# >  - Argument 'ksize' is required to be an integer
# >  - Argument 'ksize' is required to be an integer

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPColab/images/images/lena256.jpg')
print(gimg.shape)
gimg = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg, cmap='gray')
# Out:
# (256, 256, 3)

# %%
blurimage = cv2.GaussianBlur(outimage, (7, 7), 5)

# %%
edgeimage = cv2.addWeighted(gimg, 1, outimg, -1, 0)
cv2_imshow(edgeimage)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-1393074031.py in <cell line: 0>()
# ----> 1 edgeimage = cv2.addWeighted(gimg, 1, outimg, -1, 0)
#       2 cv2_imshow(edgeimage)
#
# error: OpenCV(4.12.0) /io/opencv/modules/core/src/arithm.cpp:662: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'arithm_op'

# %%
unsharpimage = cv2.addWeighted(gimg, 2, edgeimage, -1, 0)
cv2_imshow(unsharpimage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2052592650.py in <cell line: 0>()
# ----> 1 unsharpimage = cv2.addWeighted(gimg, 2, edgeimage, -1, 0)
#       2 cv2_imshow(unsharpimage)
#
# NameError: name 'edgeimage' is not defined

# %%
kernel3 = np.ones((3, 3), np.float32)/9
kernel3[0][0] = -1/9
kernel3[0][1] = -1/9
kernel3[0][2] = -1/9
kernel3[1][0] = -1/9
kernel3[1][1] = 8/9
kernel3[1][2] = -1/9
kernel3[2][0] = -1/9
kernel3[2][1] = -1/9
kernel3[2][2] = -1/9
