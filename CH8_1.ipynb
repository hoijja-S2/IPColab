# %% [markdown]
# <a href="https://colab.research.google.com/github/hoijja-S2/IPColab/blob/main/CH8_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np #이미지는 기본적으로 2차원 배열이기 때문
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPColab/images/images/char.bmp')
print(gimg.shape)
gimg = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg, cmap='gray')
#cv2_imshow(gimg)
# Out:
# (256, 256, 3)

# %%
kernel = np.ones((7,7),np.uint8)
dilateimg = cv2.dilate(gimg,kernel,iterations = 1)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeimg = dilateimg - gimg
cv2_imshow(edgeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPColab/images/images/milkdrop.bmp')
print(gimg.shape)
gimg = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg, cmap='gray')
#cv2_imshow(gimg)
# Out:
# (256, 256, 3)

# %%
kernel = np.ones((3,3),np.uint8)
dilateimg = cv2.dilate(gimg,kernel,iterations = 3)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gBin = np.zeros((gimg.shape[0],gimg.shape[1]), dtype=np.uint8)

threshold = 150

for i in range(gimg.shape[0]):
  for j in range(gimg.shape[1]):
    if gimg[i,j] > threshold:
      gBin[i,j] = 255

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3),np.uint8)
dilateimg = cv2.dilate(gBin,kernel,iterations = 3)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
#kernel = cv2.getStructuringElement(cv2.MORPH_RECT,(3,3))
#kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(3,3))
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
dilateimg = cv2.dilate(gBin,kernel,iterations = 3)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
