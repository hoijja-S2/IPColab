# %% [markdown]
# <a href="https://colab.research.google.com/github/hoijja-S2/IPColab/blob/main/CH8_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np #이미지는 기본적으로 2차원 배열이기 때문
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPColab/images/images/rice.bmp')
print(gimg.shape)
gimg = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg, cmap='gray')
#cv2_imshow(gimg)
# Out:
# (256, 256, 3)

# %%
kernel = np.ones((3,3),np.uint8)
erosion = cv2.erode(gimg,kernel,iterations = 1)
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([erosion],[0],None,[256],[0,256])
plt.plot(hist)

# %%
gBin = np.zeros((gimg.shape[0], gimg.shape[1]), dtype=np.uint8)

threshold = 110

for i in range(gimg.shape[0]):
  for j in range(gimg.shape[1]):
    if erosion[i,j] > threshold:
      gBin[i,j] = 255

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
num_labels, labels = cv2.connectedComponents(gBin, connectivity=8)
print(num_labels)
# Out:
# 100

# %%
kernel = np.ones((3,3),np.uint8)
erosion = cv2.erode(gBin,kernel,iterations = 1)
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel = np.ones((3,3),np.uint8)
dilate = cv2.dilate(erosion,kernel,iterations = 1)
cv2_imshow(dilate)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
num_labels, labels = cv2.connectedComponents(dilate, connectivity=8)
print(num_labels)
# Out:
# 98

# %%
gimg = cv2.imread('/content/gdrive/My Drive/IPColab/images/images/scanimg.jpg')
print(gimg.shape)
gimg = cv2.cvtColor(gimg, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg, cmap='gray')
#cv2_imshow(gimg)
# Out:
# (480, 1622, 3)

# %%
kernel = np.ones((3,1),np.uint8)
dilate = cv2.dilate(gimg,kernel,iterations = 2)
cv2_imshow(dilate)
# Out:
# <PIL.Image.Image image mode=L size=1622x480>

# %%
kernel = np.ones((3,1),np.uint8)
erosion = cv2.erode(dilate,kernel,iterations = 2)
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=1622x480>

# %%
hist = cv2.calcHist([gimg],[0],None,[256],[0,256])
plt.plot(hist)

# %%
gBin = np.zeros((gimg.shape[0], gimg.shape[1]), dtype=np.uint8)

threshold = 110

for i in range(gimg.shape[0]):
  for j in range(gimg.shape[1]):
    if gimg[i,j] > threshold:
      gBin[i,j] = 255

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=1622x480>

# %%
kernel = np.ones((3,1),np.uint8)
dilate = cv2.dilate(gBin,kernel,iterations = 1)
cv2_imshow(dilate)
# Out:
# <PIL.Image.Image image mode=L size=1622x480>

# %%
kernel = np.ones((3,1),np.uint8)
erosion = cv2.erode(dilate,kernel,iterations = 1)
cv2_imshow(erosion)
# Out:
# <PIL.Image.Image image mode=L size=1622x480>
